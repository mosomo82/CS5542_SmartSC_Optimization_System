# %% [markdown]
# # SRSNet Training Notebook
#
# This notebook trains the SRSNet model for time series forecasting on logistics data.

# %%
pip install torch pandas scikit-learn pyyaml
# Out:
# ...
#   Using cached torch-2.10.0-cp313-cp313-win_amd64.whl.metadata (31 kB)
# ...
#   Using cached scikit_learn-1.8.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached fsspec-2026.2.0-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# ...
# Using cached torch-2.10.0-cp313-cp313-win_amd64.whl (113.8 MB)
# Using cached scikit_learn-1.8.0-cp313-cp313-win_amd64.whl (8.0 MB)
# Using cached fsspec-2026.2.0-py3-none-any.whl (202 kB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# ...
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
# ...

# %%
import torch
import pandas as pd
from sklearn.preprocessing import StandardScaler
import yaml

# Load config
with open('../src/config/config.yaml', 'r') as f:
    config = yaml.safe_load(f)

torch.manual_seed(config['random_seed'])
print('Config loaded:', config)
# Out:
# Config loaded: {'random_seed': 42, 'srsnet': {'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001}, 'remindrag': {'max_tokens': 1024, 'temperature': 0.7}, 'snowflake': {'account': '${SNOWFLAKE_ACCOUNT}', 'user': '${SNOWFLAKE_USER}', 'password': '${SNOWFLAKE_PASSWORD}', 'role': '${SNOWFLAKE_ROLE}', 'warehouse': '${SNOWFLAKE_WAREHOUSE}', 'database': '${SNOWFLAKE_DATABASE}', 'schema': '${SNOWFLAKE_SCHEMA}'}, 'aws': {'region': '${AWS_REGION}', 's3_bucket': '${S3_BUCKET}', 'role_arn': '${SNOWFLAKE_ROLE_ARN}'}, 'datasets': {'dataco_path': 'data/DataCoSupplyChainDataset.csv', 'accidents_path': 'data/US_Accidents_March23.csv', 'bridges_path': 'data/NationalBridgeInventory.csv'}}

# %%
# Placeholder for SRSNet model (implement based on NeurIPS paper)
class SRSNet(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = torch.nn.Linear(10, 1)  # Placeholder
    
    def forward(self, x):
        return self.linear(x)

model = SRSNet()
print('SRSNet model initialized')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Placeholder for SRSNet model (implement based on NeurIPS paper)
# ----> 2 class SRSNet(torch.nn.Module):
#       3     def __init__(self):
#       4         super().__init__()
#
# NameError: name 'torch' is not defined

# %%
# Load and preprocess data (placeholder)
# df = pd.read_csv('data/preprocessed_logistics.csv')
print('Data loading and training would go here')

# Training loop placeholder
optimizer = torch.optim.Adam(model.parameters(), lr=config['srsnet']['learning_rate'])
for epoch in range(config['srsnet']['epochs']):
    # loss.backward()
    # optimizer.step()
    pass

print('Training completed')
